# %% [markdown]
# ![contional%20probability.png](attachment:contional%20probability.png)

# %% [markdown]
# ## Conditional Probability is an event happening given that another event has already

# %% [markdown]
# ## occured & consider relationship b/n two events and calculates the like of one event

# %% [markdown]
# # happening based on the occurrence of the other event

# %% [markdown]
# # NEXT PART WILL DISCUSS THINGS WE CAN DO IN Conditional Probability
